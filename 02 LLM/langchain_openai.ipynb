# %%
from langchain_openai.chat_models import ChatOpenAI
from config import OPEN_AI_KEY as api_key

# %%
chat = ChatOpenAI(model="gpt-5.6-luna", model_kwargs={"seed": 365}, temperature=0, api_key=api_key, seed=365)
response = chat.invoke("I've recently adopted a dog. Could you suggest some dog names?")
# Out:
# /home/kramstyles/miniconda3/envs/open-ai/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3688: UserWarning: Parameters {'seed'} should be specified explicitly. Instead they were passed in as part of `model_kwargs` parameter.
#   if await self.run_code(code, result, async_=asy):

# %%
print(response.content)
# Out:
# Congratulations! Here are some dog-name ideas by style:
#
# **Classic:** Max, Daisy, Charlie, Lucy, Cooper, Sadie
# **Cute:** Mochi, Biscuit, Waffles, Peanut, Teddy, Noodle
# **Nature-inspired:** Willow, River, Sunny, Clover, Maple, Aspen
# **Funny:** Sir Barks-a-Lot, Pickle, Meatball, Tater Tot, Snoop Dogg, Chewbarka
# **Strong:** Bear, Scout, Thor, Kona, Atlas, Nova
# **Elegant:** Winston, Archie, Ruby, Stella, Olive, Winston
# **Unique:** Ziggy, Nimbus, Koda, Pixel, Fig, Echo
#
# A few especially versatile choices: **Scout, Maple, Mochi, Cooper, Nova, and Teddy**.

# %%
chat = ChatOpenAI(model="gpt-5.6-luna", temperature=0, api_key=api_key, seed=365, max_completion_tokens=100)
response = chat.invoke("I've recently adopted a dog. Could you suggest some dog names?")
response
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 19, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 100, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'compute_units': None, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': 0, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna', 'system_fingerprint': None, 'id': 'chatcmpl-EJCfWlizrYQj8rI1lINBpNLb8FyMR', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--01a05bbe-b00f-7002-8078-31774e4d27ab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 100, 'total_tokens': 119, 'input_token_details': {'audio': 0, 'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'audio': 0, 'reasoning': 100}})

# %%
response
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 19, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 100, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'compute_units': None, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': 0, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna', 'system_fingerprint': None, 'id': 'chatcmpl-EJCekyzt9zhUD53qBqqSOrgpgTk8u', 'service_tier': 'default', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--01a05bbd-ed95-7d21-98b8-fd085359ec85-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 100, 'total_tokens': 119, 'input_token_details': {'audio': 0, 'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'audio': 0, 'reasoning': 100}})
