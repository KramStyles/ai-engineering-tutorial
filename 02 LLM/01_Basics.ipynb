# %%
import openai
from config import OPEN_AI_KEY as api_key

openai.api_key = api_key
# Out:
# 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
