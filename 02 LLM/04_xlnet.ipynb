# %% [markdown]
# ### Text classification with XLNET

# %%
import random
import re

from cleantext import clean
import datasets
import encodings
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from transformers import Trainer, pipeline, TrainingArguments, XLNetForSequenceClassification, XLNetTokenizer
import torch

# %% [markdown]
# ### Preprocess data

# %%
data_train = pd.read_csv('emotions_data/emotion-labels-train.csv')
data_test = pd.read_csv('emotions_data/emotion-labels-test.csv')
data_val = pd.read_csv('emotions_data/emotion-labels-val.csv')
